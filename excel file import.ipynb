# %%
import pandas as pd
data = pd.read_csv("kc_house_data .csv")
data
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 2      5631500400   2/25/2015   180000.0         2       1.00          770
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# 7      2008000270   1/15/2015   291850.0         3       1.50         1060
# 8      2414600126   4/15/2015   229500.0         3       1.00         1780
# 9      3793500160   3/12/2015   323000.0         3       2.50         1890
# 10     1736800520    4/3/2015   662500.0         3       2.50         3560
# ...

# %%
x =pd.DataFrame(data["price"])
x
# Out:
#            price
# 0       221900.0
# 1       538000.0
# 2       180000.0
# 3       604000.0
# 4       510000.0
# 5      1230000.0
# 6       257500.0
# 7       291850.0
# 8       229500.0
# 9       323000.0
# 10      662500.0
# 11      468000.0
# 12      310000.0
# 13      400000.0
# 14      530000.0
# 15      650000.0
# 16      395000.0
# 17      485000.0
# 18      189000.0
# 19      230000.0
# 20      385000.0
# 21     2000000.0
# 22      285000.0
# 23      252700.0
# 24      329000.0
# 25      233000.0
# 26      937000.0
# 27      667000.0
# 28      438000.0
# 29      719000.0
# ...          ...
# 21567   399950.0
# 21568   380000.0
# 21569   270000.0
# 21570   505000.0
# 21571   385000.0
# 21572   414500.0
# 21573   347500.0
# 21574  1220000.0
# 21575   572000.0
# 21576   475000.0
# 21577  1090000.0
# 21578   350000.0
# 21579   520000.0
# 21580   679950.0
# 21581  1580000.0
# 21582   541800.0
# 21583   810000.0
# 21584  1540000.0
# 21585   467000.0
# 21586   224000.0
# ...

# %%
x["idd"] =  data["id"]
x
# Out:
#            price         idd
# 0       221900.0  7129300520
# 1       538000.0  6414100192
# 2       180000.0  5631500400
# 3       604000.0  2487200875
# 4       510000.0  1954400510
# 5      1230000.0  7237550310
# 6       257500.0  1321400060
# 7       291850.0  2008000270
# 8       229500.0  2414600126
# 9       323000.0  3793500160
# 10      662500.0  1736800520
# 11      468000.0  9212900260
# 12      310000.0   114101516
# 13      400000.0  6054650070
# 14      530000.0  1175000570
# 15      650000.0  9297300055
# 16      395000.0  1875500060
# 17      485000.0  6865200140
# 18      189000.0    16000397
# 19      230000.0  7983200060
# 20      385000.0  6300500875
# 21     2000000.0  2524049179
# 22      285000.0  7137970340
# 23      252700.0  8091400200
# 24      329000.0  3814700200
# 25      233000.0  1202000200
# 26      937000.0  1794500383
# 27      667000.0  3303700376
# 28      438000.0  5101402488
# 29      719000.0  1873100390
# ...          ...         ...
# ...

# %%
data2 = pd.DataFrame(data[{"id","price","bedrooms"}])

# %%
data2
# Out:
#        bedrooms          id      price
# 0             3  7129300520   221900.0
# 1             3  6414100192   538000.0
# 2             2  5631500400   180000.0
# 3             4  2487200875   604000.0
# 4             3  1954400510   510000.0
# 5             4  7237550310  1230000.0
# 6             3  1321400060   257500.0
# 7             3  2008000270   291850.0
# 8             3  2414600126   229500.0
# 9             3  3793500160   323000.0
# 10            3  1736800520   662500.0
# 11            2  9212900260   468000.0
# 12            3   114101516   310000.0
# 13            3  6054650070   400000.0
# 14            5  1175000570   530000.0
# 15            4  9297300055   650000.0
# 16            3  1875500060   395000.0
# 17            4  6865200140   485000.0
# 18            2    16000397   189000.0
# 19            3  7983200060   230000.0
# 20            4  6300500875   385000.0
# 21            3  2524049179  2000000.0
# 22            5  7137970340   285000.0
# ...
