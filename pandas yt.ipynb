# %%
import pandas as pd
df = pd.read_csv("kc_house_data .csv")
df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 2      5631500400   2/25/2015   180000.0         2       1.00          770
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6      1321400060   6/27/2014   257500.0         3       2.25         1715
# 7      2008000270   1/15/2015   291850.0         3       1.50         1060
# 8      2414600126   4/15/2015   229500.0         3       1.00         1780
# 9      3793500160   3/12/2015   323000.0         3       2.50         1890
# 10     1736800520    4/3/2015   662500.0         3       2.50         3560
# ...

# %%
df["sqft_living"].max()
# Out:
# 13540

# %%
df['date'][df['floors']==3]
# Out:
# 31        12/1/2014
# 63        12/7/2014
# 116       6/26/2014
# 134       1/26/2015
# 139        5/7/2014
# 406        8/6/2014
# 438        7/8/2014
# 610       12/9/2014
# 626        8/8/2014
# 643       5/12/2015
# 663       5/27/2014
# 666       5/14/2014
# 667       9/30/2014
# 844       12/9/2014
# 886       7/15/2014
# 952       5/21/2014
# 959      11/12/2014
# 984       5/29/2014
# 1097       4/6/2015
# 1106     12/30/2014
# 1204      5/20/2014
# 1242      6/24/2014
# 1254     11/17/2014
# 1265     11/13/2014
# 1660      3/30/2015
# 1687      7/11/2014
# 1692      8/12/2014
# 1842      4/13/2015
# 1846       2/3/2015
# 1929      2/11/2015
#             ...
# 21440     2/25/2015
# 21443      6/2/2014
# 21446     8/13/2014
# 21450      9/2/2014
# 21465     5/27/2014
# 21473     1/20/2015
# 21475     3/27/2015
# 21476     4/17/2015
# 21482     7/14/2014
# 21491      8/8/2014
# 21492     6/18/2014
# 21496     3/31/2015
# 21500     10/1/2014
# 21502     7/11/2014
# ...

# %%
df["grade"].mean()
# Out:
# 7.657915451220076

# %%
df[df.yr_built == 1955]
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014   221900.0         3       1.00         1180
# 50     5245600105   9/16/2014   228000.0         3       1.00         1190
# 172    1999700045    5/2/2014   313000.0         3       1.50         1340
# 256    7972601890  10/20/2014   385000.0         4       1.75         2360
# 331    2946001550   4/16/2015   279000.0         6       1.75         2240
# 355    6607000126    6/4/2014   375000.0         4       1.75         2200
# 421    6073200075   7/30/2014   625000.0         3       1.75         1600
# 480    2205700350   11/4/2014   378500.0         4       1.75         1700
# 774    2205500575    2/9/2015   390000.0         3       1.00         1200
# 912    2115200125   9/19/2014   384000.0         4       1.75         2100
# 991    1455600030    1/8/2015   645000.0         4       2.00         2780
# ...

# %%
df.bedrooms.sum()
# Out:
# 72851

# %%
df.bedrooms.min()
# Out:
# 1

# %%
df.bedrooms.max()
# Out:
# 33

# %%
df.bedrooms.mean()
# Out:
# 3.3731999814789093

# %%
df.bedrooms.median()
# Out:
# 3.0

# %%
df.groupby('yr_built').mean()
# Out:
#                     id          price  bedrooms  bathrooms  sqft_living  \
# yr_built
# 1900      5.060402e+09  581536.632184  3.275862   1.729885  1732.011494
# 1901      5.036920e+09  557108.344828  3.620690   1.577586  1763.620690
# 1902      4.280460e+09  673192.592593  3.555556   1.925926  1919.629630
# 1903      4.508135e+09  480958.195652  3.065217   1.505435  1507.739130
# 1904      4.542878e+09  583867.755556  2.911111   1.500000  1603.177778
# 1905      4.427030e+09  753443.932432  3.310811   1.864865  1965.810811
# 1906      3.719887e+09  670027.663043  3.228261   1.777174  1802.228261
# 1907      4.281123e+09  676324.476923  3.261538   1.784615  1904.276923
# 1908      4.809381e+09  564499.848837  3.081395   1.636628  1699.639535
# 1909      4.592798e+09  696448.989362  3.191489   1.824468  1900.106383
# 1910      4.639921e+09  671671.835821  3.037313   1.783582  1880.716418
# 1911      4.643895e+09  632584.246575  3.547945   1.729452  1893.835616
# ...

# %%
df.groupby('yr_built').mean()[['bedrooms']]
# Out:
#           bedrooms
# yr_built
# 1900      3.275862
# 1901      3.620690
# 1902      3.555556
# 1903      3.065217
# 1904      2.911111
# 1905      3.310811
# 1906      3.228261
# 1907      3.261538
# 1908      3.081395
# 1909      3.191489
# 1910      3.037313
# 1911      3.547945
# 1912      3.151899
# 1913      3.637931
# 1914      3.259259
# 1915      3.234375
# 1916      3.126582
# 1917      3.160714
# 1918      2.958333
# 1919      3.011364
# 1920      3.010204
# 1921      3.315789
# 1922      2.978947
# 1923      2.928571
# 1924      2.877698
# 1925      3.200000
# 1926      3.222222
# 1927      3.173913
# 1928      3.150794
# 1929      3.324561
# ...            ...
# 1986      3.362791
# 1987      3.384354
# 1988      3.374074
# 1989      3.486207
# 1990      3.485804
# 1991      3.482143
# 1992      3.474747
# 1993      3.514851
# 1994      3.457831
# 1995      3.437870
# 1996      3.618557
# 1997      3.581921
# 1998      3.623431
# 1999      3.585551
# 2000      3.527523
# ...

# %%
df.groupby('yr_built').count()
# Out:
#            id  date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# yr_built
# 1900       87    87     87        87         87           87        87
# 1901       29    29     29        29         29           29        29
# 1902       27    27     27        27         27           27        27
# 1903       46    46     46        46         46           46        46
# 1904       45    45     45        45         45           45        45
# 1905       74    74     74        74         74           74        74
# 1906       92    92     92        92         92           92        92
# 1907       65    65     65        65         65           65        65
# 1908       86    86     86        86         86           86        86
# 1909       94    94     94        94         94           94        94
# 1910      134   134    134       134        134          134       134
# 1911       73    73     73        73         73           73        73
# ...

# %%
df.groupby('bedrooms').count()[['bathrooms']]
# Out:
#           bathrooms
# bedrooms
# 1               196
# 2              2760
# 3              9824
# 4              6882
# 5              1601
# 6               272
# 7                38
# 8                13
# 9                 6
# 10                3
# 11                1
# 33                1

# %%
dzoo = pd.read_csv("zoo.csv")
dzoo
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 1   elephant     1002         600
# 2   elephant     1003         550
# 3      tiger     1004         300
# 4      tiger     1005         320
# 5      tiger     1006         330
# 6      tiger     1007         290
# 7      tiger     1008         310
# 8      zebra     1009         200
# 9      zebra     1010         220
# 10     zebra     1011         240
# 11     zebra     1012         230
# 12     zebra     1013         220
# 13     zebra     1014         100
# 14     zebra     1015          80
# 15      lion     1016         420
# 16      lion     1017         600
# 17      lion     1018         500
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 20  kangaroo     1021         430
# 21  kangaroo     1022         410

# %%
dzoo.groupby('animal').mean()
# Out:
#           uniq_id  water_need
# animal
# elephant   1002.0  550.000000
# kangaroo   1021.0  416.666667
# lion       1017.5  477.500000
# tiger      1006.0  310.000000
# zebra      1012.0  184.285714

# %%
zoo_eats = pd.DataFrame({"animal":['elephant','tiger','zebra','kangaroo','giraffe'], "food":['vegetables','food','vegetables','vegetables','vegetables']})
zoo_eats
# Out:
#      animal        food
# 0  elephant  vegetables
# 1     tiger        food
# 2     zebra  vegetables
# 3  kangaroo  vegetables
# 4   giraffe  vegetables

# %%
zoo_eats = pd.DataFrame([['elephant','vegetables'],['tiger','meat'],['zebra','vegetables'],['kangaroo','vegetables'],['giraffe','vegetables']], columns = ['animal','food'])
zoo_eats
# Out:
#      animal        food
# 0  elephant  vegetables
# 1     tiger        meat
# 2     zebra  vegetables
# 3  kangaroo  vegetables
# 4   giraffe  vegetables

# %%
dzoo.merge(zoo_eats)
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15  kangaroo     1020         410  vegetables
# 16  kangaroo     1021         430  vegetables
# 17  kangaroo     1022         410  vegetables

# %%
zoo_eats.merge(dzoo)
# Out:
#       animal        food  uniq_id  water_need
# 0   elephant  vegetables     1001         500
# 1   elephant  vegetables     1002         600
# 2   elephant  vegetables     1003         550
# 3      tiger        meat     1004         300
# 4      tiger        meat     1005         320
# 5      tiger        meat     1006         330
# 6      tiger        meat     1007         290
# 7      tiger        meat     1008         310
# 8      zebra  vegetables     1009         200
# 9      zebra  vegetables     1010         220
# 10     zebra  vegetables     1011         240
# 11     zebra  vegetables     1012         230
# 12     zebra  vegetables     1013         220
# 13     zebra  vegetables     1014         100
# 14     zebra  vegetables     1015          80
# 15  kangaroo  vegetables     1020         410
# 16  kangaroo  vegetables     1021         430
# 17  kangaroo  vegetables     1022         410

# %%
dzoo.merge(zoo_eats, how = 'outer')
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant   1001.0       500.0  vegetables
# 1   elephant   1002.0       600.0  vegetables
# 2   elephant   1003.0       550.0  vegetables
# 3      tiger   1004.0       300.0        meat
# 4      tiger   1005.0       320.0        meat
# 5      tiger   1006.0       330.0        meat
# 6      tiger   1007.0       290.0        meat
# 7      tiger   1008.0       310.0        meat
# 8      zebra   1009.0       200.0  vegetables
# 9      zebra   1010.0       220.0  vegetables
# 10     zebra   1011.0       240.0  vegetables
# 11     zebra   1012.0       230.0  vegetables
# 12     zebra   1013.0       220.0  vegetables
# 13     zebra   1014.0       100.0  vegetables
# 14     zebra   1015.0        80.0  vegetables
# 15      lion   1016.0       420.0         NaN
# 16      lion   1017.0       600.0         NaN
# 17      lion   1018.0       500.0         NaN
# 18      lion   1019.0       390.0         NaN
# ...

# %%
dzoo.merge(zoo_eats, how = 'left')
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15      lion     1016         420         NaN
# 16      lion     1017         600         NaN
# 17      lion     1018         500         NaN
# 18      lion     1019         390         NaN
# ...

# %%
zoo_eats.merge(dzoo, how = 'left')
# Out:
#       animal        food  uniq_id  water_need
# 0   elephant  vegetables   1001.0       500.0
# 1   elephant  vegetables   1002.0       600.0
# 2   elephant  vegetables   1003.0       550.0
# 3      tiger        meat   1004.0       300.0
# 4      tiger        meat   1005.0       320.0
# 5      tiger        meat   1006.0       330.0
# 6      tiger        meat   1007.0       290.0
# 7      tiger        meat   1008.0       310.0
# 8      zebra  vegetables   1009.0       200.0
# 9      zebra  vegetables   1010.0       220.0
# 10     zebra  vegetables   1011.0       240.0
# 11     zebra  vegetables   1012.0       230.0
# 12     zebra  vegetables   1013.0       220.0
# 13     zebra  vegetables   1014.0       100.0
# 14     zebra  vegetables   1015.0        80.0
# 15  kangaroo  vegetables   1020.0       410.0
# 16  kangaroo  vegetables   1021.0       430.0
# 17  kangaroo  vegetables   1022.0       410.0
# 18   giraffe  vegetables      NaN         NaN

# %%
dzoo.merge(zoo_eats, how = 'left')
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15      lion     1016         420         NaN
# 16      lion     1017         600         NaN
# 17      lion     1018         500         NaN
# 18      lion     1019         390         NaN
# ...

# %%
dzoo.merge(zoo_eats, how = 'inner')
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15  kangaroo     1020         410  vegetables
# 16  kangaroo     1021         430  vegetables
# 17  kangaroo     1022         410  vegetables

# %%
dzoo.merge(zoo_eats, how = 'left', left_on = 'animal', right_on = 'animal')
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15      lion     1016         420         NaN
# 16      lion     1017         600         NaN
# 17      lion     1018         500         NaN
# 18      lion     1019         390         NaN
# ...

# %%
dzoo.sort_values('water_need')
# Out:
#       animal  uniq_id  water_need
# 14     zebra     1015          80
# 13     zebra     1014         100
# 8      zebra     1009         200
# 9      zebra     1010         220
# 12     zebra     1013         220
# 11     zebra     1012         230
# 10     zebra     1011         240
# 6      tiger     1007         290
# 3      tiger     1004         300
# 7      tiger     1008         310
# 4      tiger     1005         320
# 5      tiger     1006         330
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 15      lion     1016         420
# 20  kangaroo     1021         430
# 17      lion     1018         500
# 0   elephant     1001         500
# 2   elephant     1003         550
# 16      lion     1017         600
# 1   elephant     1002         600

# %%
dzoo.sort_values(by = ['animal','water_need'])
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1001         500
# 2   elephant     1003         550
# 1   elephant     1002         600
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 20  kangaroo     1021         430
# 18      lion     1019         390
# 15      lion     1016         420
# 17      lion     1018         500
# 16      lion     1017         600
# 6      tiger     1007         290
# 3      tiger     1004         300
# 7      tiger     1008         310
# 4      tiger     1005         320
# 5      tiger     1006         330
# 14     zebra     1015          80
# 13     zebra     1014         100
# 8      zebra     1009         200
# 9      zebra     1010         220
# 12     zebra     1013         220
# 11     zebra     1012         230
# 10     zebra     1011         240

# %%
dzoo.sort_values(by = ['water_need'])
# Out:
#       animal  uniq_id  water_need
# 14     zebra     1015          80
# 13     zebra     1014         100
# 8      zebra     1009         200
# 9      zebra     1010         220
# 12     zebra     1013         220
# 11     zebra     1012         230
# 10     zebra     1011         240
# 6      tiger     1007         290
# 3      tiger     1004         300
# 7      tiger     1008         310
# 4      tiger     1005         320
# 5      tiger     1006         330
# 18      lion     1019         390
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 15      lion     1016         420
# 20  kangaroo     1021         430
# 17      lion     1018         500
# 0   elephant     1001         500
# 2   elephant     1003         550
# 16      lion     1017         600
# 1   elephant     1002         600

# %%
dzoo.sort_values(by = ['water_need'], ascending = False)
# Out:
#       animal  uniq_id  water_need
# 1   elephant     1002         600
# 16      lion     1017         600
# 2   elephant     1003         550
# 0   elephant     1001         500
# 17      lion     1018         500
# 20  kangaroo     1021         430
# 15      lion     1016         420
# 19  kangaroo     1020         410
# 21  kangaroo     1022         410
# 18      lion     1019         390
# 5      tiger     1006         330
# 4      tiger     1005         320
# 7      tiger     1008         310
# 3      tiger     1004         300
# 6      tiger     1007         290
# 10     zebra     1011         240
# 11     zebra     1012         230
# 9      zebra     1010         220
# 12     zebra     1013         220
# 8      zebra     1009         200
# 13     zebra     1014         100
# 14     zebra     1015          80

# %%
dzoo.sort_values(by = ['water_need'], ascending = False).reset_index()
# Out:
#     index    animal  uniq_id  water_need
# 0       1  elephant     1002         600
# 1      16      lion     1017         600
# 2       2  elephant     1003         550
# 3       0  elephant     1001         500
# 4      17      lion     1018         500
# 5      20  kangaroo     1021         430
# 6      15      lion     1016         420
# 7      19  kangaroo     1020         410
# 8      21  kangaroo     1022         410
# 9      18      lion     1019         390
# 10      5     tiger     1006         330
# 11      4     tiger     1005         320
# 12      7     tiger     1008         310
# 13      3     tiger     1004         300
# 14      6     tiger     1007         290
# 15     10     zebra     1011         240
# 16     11     zebra     1012         230
# 17      9     zebra     1010         220
# 18     12     zebra     1013         220
# 19      8     zebra     1009         200
# 20     13     zebra     1014         100
# 21     14     zebra     1015          80

# %%
dzoo.sort_values(by = ['water_need'], ascending = False).reset_index(drop = True)
# Out:
#       animal  uniq_id  water_need
# 0   elephant     1002         600
# 1       lion     1017         600
# 2   elephant     1003         550
# 3   elephant     1001         500
# 4       lion     1018         500
# 5   kangaroo     1021         430
# 6       lion     1016         420
# 7   kangaroo     1020         410
# 8   kangaroo     1022         410
# 9       lion     1019         390
# 10     tiger     1006         330
# 11     tiger     1005         320
# 12     tiger     1008         310
# 13     tiger     1004         300
# 14     tiger     1007         290
# 15     zebra     1011         240
# 16     zebra     1012         230
# 17     zebra     1010         220
# 18     zebra     1013         220
# 19     zebra     1009         200
# 20     zebra     1014         100
# 21     zebra     1015          80

# %%
zoo_eats.merge(dzoo,how = 'left').fillna('unknown')
# Out:
#       animal        food  uniq_id water_need
# 0   elephant  vegetables     1001        500
# 1   elephant  vegetables     1002        600
# 2   elephant  vegetables     1003        550
# 3      tiger        meat     1004        300
# 4      tiger        meat     1005        320
# 5      tiger        meat     1006        330
# 6      tiger        meat     1007        290
# 7      tiger        meat     1008        310
# 8      zebra  vegetables     1009        200
# 9      zebra  vegetables     1010        220
# 10     zebra  vegetables     1011        240
# 11     zebra  vegetables     1012        230
# 12     zebra  vegetables     1013        220
# 13     zebra  vegetables     1014        100
# 14     zebra  vegetables     1015         80
# 15  kangaroo  vegetables     1020        410
# 16  kangaroo  vegetables     1021        430
# 17  kangaroo  vegetables     1022        410
# 18   giraffe  vegetables  unknown    unknown

# %%
dzoo.merge(zoo_eats, how = 'left').fillna('meat')
# Out:
#       animal  uniq_id  water_need        food
# 0   elephant     1001         500  vegetables
# 1   elephant     1002         600  vegetables
# 2   elephant     1003         550  vegetables
# 3      tiger     1004         300        meat
# 4      tiger     1005         320        meat
# 5      tiger     1006         330        meat
# 6      tiger     1007         290        meat
# 7      tiger     1008         310        meat
# 8      zebra     1009         200  vegetables
# 9      zebra     1010         220  vegetables
# 10     zebra     1011         240  vegetables
# 11     zebra     1012         230  vegetables
# 12     zebra     1013         220  vegetables
# 13     zebra     1014         100  vegetables
# 14     zebra     1015          80  vegetables
# 15      lion     1016         420        meat
# 16      lion     1017         600        meat
# 17      lion     1018         500        meat
# 18      lion     1019         390        meat
# ...

# %%
dzoo.merge(zoo_eats, how = 'left').water_need
# Out:
# 0     500
# 1     600
# 2     550
# 3     300
# 4     320
# 5     330
# 6     290
# 7     310
# 8     200
# 9     220
# 10    240
# 11    230
# 12    220
# 13    100
# 14     80
# 15    420
# 16    600
# 17    500
# 18    390
# 19    410
# 20    430
# 21    410
# Name: water_need, dtype: int64
